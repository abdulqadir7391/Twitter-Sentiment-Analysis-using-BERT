# %%
#general purpose packages
import numpy as np
import pandas as pd
import tensorflow as tf
import matplotlib.pyplot as plt
import seaborn as sns

#data processing
import re, string
import emoji
import nltk

from sklearn import preprocessing
from imblearn.over_sampling import RandomOverSampler
from sklearn.model_selection import train_test_split


#Naive Bayes
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.naive_bayes import MultinomialNB

#transformers
from transformers import BertTokenizerFast
from transformers import TFBertModel
from transformers import RobertaTokenizerFast
from transformers import TFRobertaModel

#keras
import tensorflow as tf
from tensorflow import keras


#metrics
from sklearn.metrics import accuracy_score, f1_score
from sklearn.metrics import classification_report, confusion_matrix

#set seed for reproducibility
seed=42

# #set style for plots
# sns.set_style("whitegrid")
# sns.despine()
# sns.style.use("whitegrid")
# plt.rc("figure", autolayout=True)
# plt.rc("axes", labelweight="bold", labelsize="large", titleweight="bold", titlepad=10)

# %% [markdown]
# 1. Dependencies

# %%
pip install tweepy pymongo streamlit plotly pandas transformers torch scikit-learn reportlab
# Out:
# Collecting tweepy
#   Downloading tweepy-4.16.0-py3-none-any.whl.metadata (3.3 kB)
# Collecting pymongo
#   Downloading pymongo-4.15.0-cp312-cp312-win_amd64.whl.metadata (22 kB)
# Requirement already satisfied: streamlit in f:\language courses videos\machine learning\complete data science, machine learning, deep learning, nlp bootcamp 2024-10\python\venv\lib\site-packages (1.41.1)
# Collecting plotly
#   Downloading plotly-6.3.0-py3-none-any.whl.metadata (8.5 kB)
# Requirement already satisfied: pandas in f:\language courses videos\machine learning\complete data science, machine learning, deep learning, nlp bootcamp 2024-10\python\venv\lib\site-packages (2.2.3)
# Requirement already satisfied: transformers in f:\language courses videos\machine learning\complete data science, machine learning, deep learning, nlp bootcamp 2024-10\python\venv\lib\site-packages (4.48.3)
# Requirement already satisfied: torch in f:\language courses videos\machine learning\complete data science, machine learning, deep learning, nlp bootcamp 2024-10\python\venv\lib\site-packages (2.6.0)
# Requirement already satisfied: scikit-learn in f:\language courses videos\machine learning\complete data science, machine learning, deep learning, nlp bootcamp 2024-10\python\venv\lib\site-packages (1.6.1)
# Collecting reportlab
#   Downloading reportlab-4.4.3-py3-none-any.whl.metadata (1.7 kB)
# Collecting oauthlib<4,>=3.2.0 (from tweepy)
#   Downloading oauthlib-3.3.1-py3-none-any.whl.metadata (7.9 kB)
# Requirement already satisfied: requests<3,>=2.27.0 in f:\language courses videos\machine learning\complete data science, machine learning, deep learning, nlp bootcamp 2024-10\python\venv\lib\site-packages (from tweepy) (2.32.3)
# Collecting requests-oauthlib<3,>=1.2.0 (from tweepy)
#   Downloading requests_oauthlib-2.0.0-py2.py3-none-any.whl.metadata (11 kB)
# Collecting dnspython<3.0.0,>=1.16.0 (from pymongo)
#   Downloading dnspython-2.8.0-py3-none-any.whl.metadata (5.7 kB)
# Requirement already satisfied: altair<6,>=4.0 in f:\language courses videos\machine learning\complete data science, machine learning, deep learning, nlp bootcamp 2024-10\python\venv\lib\site-packages (from streamlit) (5.5.0)
# Requirement already satisfied: blinker<2,>=1.0.0 in f:\language courses videos\machine learning\complete data science, machine learning, deep learning, nlp bootcamp 2024-10\python\venv\lib\site-packages (from streamlit) (1.9.0)
# Requirement already satisfied: cachetools<6,>=4.0 in f:\language courses videos\machine learning\complete data science, machine learning, deep learning, nlp bootcamp 2024-10\python\venv\lib\site-packages (from streamlit) (5.5.1)
# Requirement already satisfied: click<9,>=7.0 in f:\language courses videos\machine learning\complete data science, machine learning, deep learning, nlp bootcamp 2024-10\python\venv\lib\site-packages (from streamlit) (8.1.8)
# Requirement already satisfied: numpy<3,>=1.23 in f:\language courses videos\machine learning\complete data science, machine learning, deep learning, nlp bootcamp 2024-10\python\venv\lib\site-packages (from streamlit) (2.1.3)
# Requirement already satisfied: packaging<25,>=20 in f:\language courses videos\machine learning\complete data science, machine learning, deep learning, nlp bootcamp 2024-10\python\venv\lib\site-packages (from streamlit) (24.2)
# Requirement already satisfied: pillow<12,>=7.1.0 in f:\language courses videos\machine learning\complete data science, machine learning, deep learning, nlp bootcamp 2024-10\python\venv\lib\site-packages (from streamlit) (11.1.0)
# Requirement already satisfied: protobuf<6,>=3.20 in f:\language courses videos\machine learning\complete data science, machine learning, deep learning, nlp bootcamp 2024-10\python\venv\lib\site-packages (from streamlit) (5.29.3)
# Requirement already satisfied: pyarrow>=7.0 in f:\language courses videos\machine learning\complete data science, machine learning, deep learning, nlp bootcamp 2024-10\python\venv\lib\site-packages (from streamlit) (19.0.0)
# Requirement already satisfied: rich<14,>=10.14.0 in f:\language courses videos\machine learning\complete data science, machine learning, deep learning, nlp bootcamp 2024-10\python\venv\lib\site-packages (from streamlit) (13.9.4)
# Requirement already satisfied: tenacity<10,>=8.1.0 in f:\language courses videos\machine learning\complete data science, machine learning, deep learning, nlp bootcamp 2024-10\python\venv\lib\site-packages (from streamlit) (9.0.0)
# Requirement already satisfied: toml<2,>=0.10.1 in f:\language courses videos\machine learning\complete data science, machine learning, deep learning, nlp bootcamp 2024-10\python\venv\lib\site-packages (from streamlit) (0.10.2)
# Requirement already satisfied: typing-extensions<5,>=4.3.0 in f:\language courses videos\machine learning\complete data science, machine learning, deep learning, nlp bootcamp 2024-10\python\venv\lib\site-packages (from streamlit) (4.12.2)
# Requirement already satisfied: watchdog<7,>=2.1.5 in f:\language courses videos\machine learning\complete data science, machine learning, deep learning, nlp bootcamp 2024-10\python\venv\lib\site-packages (from streamlit) (6.0.0)
# Requirement already satisfied: gitpython!=3.1.19,<4,>=3.0.7 in f:\language courses videos\machine learning\complete data science, machine learning, deep learning, nlp bootcamp 2024-10\python\venv\lib\site-packages (from streamlit) (3.1.44)
# Requirement already satisfied: pydeck<1,>=0.8.0b4 in f:\language courses videos\machine learning\complete data science, machine learning, deep learning, nlp bootcamp 2024-10\python\venv\lib\site-packages (from streamlit) (0.9.1)
# Requirement already satisfied: tornado<7,>=6.0.3 in f:\language courses videos\machine learning\complete data science, machine learning, deep learning, nlp bootcamp 2024-10\python\venv\lib\site-packages (from streamlit) (6.4.2)
# Requirement already satisfied: narwhals>=1.15.1 in f:\language courses videos\machine learning\complete data science, machine learning, deep learning, nlp bootcamp 2024-10\python\venv\lib\site-packages (from plotly) (1.25.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in f:\language courses videos\machine learning\complete data science, machine learning, deep learning, nlp bootcamp 2024-10\python\venv\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in f:\language courses videos\machine learning\complete data science, machine learning, deep learning, nlp bootcamp 2024-10\python\venv\lib\site-packages (from pandas) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in f:\language courses videos\machine learning\complete data science, machine learning, deep learning, nlp bootcamp 2024-10\python\venv\lib\site-packages (from pandas) (2025.1)
# Requirement already satisfied: filelock in f:\language courses videos\machine learning\complete data science, machine learning, deep learning, nlp bootcamp 2024-10\python\venv\lib\site-packages (from transformers) (3.17.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.24.0 in f:\language courses videos\machine learning\complete data science, machine learning, deep learning, nlp bootcamp 2024-10\python\venv\lib\site-packages (from transformers) (0.28.1)
# Requirement already satisfied: pyyaml>=5.1 in f:\language courses videos\machine learning\complete data science, machine learning, deep learning, nlp bootcamp 2024-10\python\venv\lib\site-packages (from transformers) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in f:\language courses videos\machine learning\complete data science, machine learning, deep learning, nlp bootcamp 2024-10\python\venv\lib\site-packages (from transformers) (2024.11.6)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in f:\language courses videos\machine learning\complete data science, machine learning, deep learning, nlp bootcamp 2024-10\python\venv\lib\site-packages (from transformers) (0.21.0)
# Requirement already satisfied: safetensors>=0.4.1 in f:\language courses videos\machine learning\complete data science, machine learning, deep learning, nlp bootcamp 2024-10\python\venv\lib\site-packages (from transformers) (0.5.2)
# Requirement already satisfied: tqdm>=4.27 in f:\language courses videos\machine learning\complete data science, machine learning, deep learning, nlp bootcamp 2024-10\python\venv\lib\site-packages (from transformers) (4.67.1)
# Requirement already satisfied: networkx in f:\language courses videos\machine learning\complete data science, machine learning, deep learning, nlp bootcamp 2024-10\python\venv\lib\site-packages (from torch) (3.4.2)
# Requirement already satisfied: jinja2 in f:\language courses videos\machine learning\complete data science, machine learning, deep learning, nlp bootcamp 2024-10\python\venv\lib\site-packages (from torch) (3.1.5)
# Requirement already satisfied: fsspec in f:\language courses videos\machine learning\complete data science, machine learning, deep learning, nlp bootcamp 2024-10\python\venv\lib\site-packages (from torch) (2025.2.0)
# Requirement already satisfied: setuptools in f:\language courses videos\machine learning\complete data science, machine learning, deep learning, nlp bootcamp 2024-10\python\venv\lib\site-packages (from torch) (75.1.0)
# Requirement already satisfied: sympy==1.13.1 in f:\language courses videos\machine learning\complete data science, machine learning, deep learning, nlp bootcamp 2024-10\python\venv\lib\site-packages (from torch) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in f:\language courses videos\machine learning\complete data science, machine learning, deep learning, nlp bootcamp 2024-10\python\venv\lib\site-packages (from sympy==1.13.1->torch) (1.3.0)
# Requirement already satisfied: scipy>=1.6.0 in f:\language courses videos\machine learning\complete data science, machine learning, deep learning, nlp bootcamp 2024-10\python\venv\lib\site-packages (from scikit-learn) (1.15.1)
# Requirement already satisfied: joblib>=1.2.0 in f:\language courses videos\machine learning\complete data science, machine learning, deep learning, nlp bootcamp 2024-10\python\venv\lib\site-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in f:\language courses videos\machine learning\complete data science, machine learning, deep learning, nlp bootcamp 2024-10\python\venv\lib\site-packages (from scikit-learn) (3.5.0)
# Requirement already satisfied: charset-normalizer in f:\language courses videos\machine learning\complete data science, machine learning, deep learning, nlp bootcamp 2024-10\python\venv\lib\site-packages (from reportlab) (3.4.1)
# Requirement already satisfied: jsonschema>=3.0 in f:\language courses videos\machine learning\complete data science, machine learning, deep learning, nlp bootcamp 2024-10\python\venv\lib\site-packages (from altair<6,>=4.0->streamlit) (4.23.0)
# Requirement already satisfied: colorama in f:\language courses videos\machine learning\complete data science, machine learning, deep learning, nlp bootcamp 2024-10\python\venv\lib\site-packages (from click<9,>=7.0->streamlit) (0.4.6)
# Requirement already satisfied: gitdb<5,>=4.0.1 in f:\language courses videos\machine learning\complete data science, machine learning, deep learning, nlp bootcamp 2024-10\python\venv\lib\site-packages (from gitpython!=3.1.19,<4,>=3.0.7->streamlit) (4.0.12)
# Requirement already satisfied: MarkupSafe>=2.0 in f:\language courses videos\machine learning\complete data science, machine learning, deep learning, nlp bootcamp 2024-10\python\venv\lib\site-packages (from jinja2->torch) (3.0.2)
# Requirement already satisfied: six>=1.5 in f:\language courses videos\machine learning\complete data science, machine learning, deep learning, nlp bootcamp 2024-10\python\venv\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: idna<4,>=2.5 in f:\language courses videos\machine learning\complete data science, machine learning, deep learning, nlp bootcamp 2024-10\python\venv\lib\site-packages (from requests<3,>=2.27.0->tweepy) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in f:\language courses videos\machine learning\complete data science, machine learning, deep learning, nlp bootcamp 2024-10\python\venv\lib\site-packages (from requests<3,>=2.27.0->tweepy) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in f:\language courses videos\machine learning\complete data science, machine learning, deep learning, nlp bootcamp 2024-10\python\venv\lib\site-packages (from requests<3,>=2.27.0->tweepy) (2025.1.31)
# Requirement already satisfied: markdown-it-py>=2.2.0 in f:\language courses videos\machine learning\complete data science, machine learning, deep learning, nlp bootcamp 2024-10\python\venv\lib\site-packages (from rich<14,>=10.14.0->streamlit) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in f:\language courses videos\machine learning\complete data science, machine learning, deep learning, nlp bootcamp 2024-10\python\venv\lib\site-packages (from rich<14,>=10.14.0->streamlit) (2.18.0)
# Requirement already satisfied: smmap<6,>=3.0.1 in f:\language courses videos\machine learning\complete data science, machine learning, deep learning, nlp bootcamp 2024-10\python\venv\lib\site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit) (5.0.2)
# Requirement already satisfied: attrs>=22.2.0 in f:\language courses videos\machine learning\complete data science, machine learning, deep learning, nlp bootcamp 2024-10\python\venv\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (25.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in f:\language courses videos\machine learning\complete data science, machine learning, deep learning, nlp bootcamp 2024-10\python\venv\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (2024.10.1)
# Requirement already satisfied: referencing>=0.28.4 in f:\language courses videos\machine learning\complete data science, machine learning, deep learning, nlp bootcamp 2024-10\python\venv\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in f:\language courses videos\machine learning\complete data science, machine learning, deep learning, nlp bootcamp 2024-10\python\venv\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (0.22.3)
# Requirement already satisfied: mdurl~=0.1 in f:\language courses videos\machine learning\complete data science, machine learning, deep learning, nlp bootcamp 2024-10\python\venv\lib\site-packages (from markdown-it-py>=2.2.0->rich<14,>=10.14.0->streamlit) (0.1.2)
# Downloading tweepy-4.16.0-py3-none-any.whl (98 kB)
# Downloading pymongo-4.15.0-cp312-cp312-win_amd64.whl (909 kB)
#    ---------------------------------------- 0.0/910.0 kB ? eta -:--:--
#    ---------------------------------------- 910.0/910.0 kB 8.3 MB/s eta 0:00:00
# Downloading plotly-6.3.0-py3-none-any.whl (9.8 MB)
#    ---------------------------------------- 0.0/9.8 MB ? eta -:--:--
#    ---------------- ----------------------- 3.9/9.8 MB 18.1 MB/s eta 0:00:01
#    ------------------------------------- -- 9.2/9.8 MB 21.1 MB/s eta 0:00:01
#    ---------------------------------------- 9.8/9.8 MB 20.3 MB/s eta 0:00:00
# Downloading reportlab-4.4.3-py3-none-any.whl (2.0 MB)
#    ---------------------------------------- 0.0/2.0 MB ? eta -:--:--
#    ---------------------------------------- 2.0/2.0 MB 21.7 MB/s eta 0:00:00
# Downloading dnspython-2.8.0-py3-none-any.whl (331 kB)
# Downloading oauthlib-3.3.1-py3-none-any.whl (160 kB)
# Downloading requests_oauthlib-2.0.0-py2.py3-none-any.whl (24 kB)
# Installing collected packages: reportlab, plotly, oauthlib, dnspython, requests-oauthlib, pymongo, tweepy
# Successfully installed dnspython-2.8.0 oauthlib-3.3.1 plotly-6.3.0 pymongo-4.15.0 reportlab-4.4.3 requests-oauthlib-2.0.0 tweepy-4.16.0
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# 2. Real-Time Tweet Streaming

# %%
import tweepy

# Twitter API credentials (use your own keys)
BEARER_TOKEN = 'AAAAAAAAAAAAAAAAAAAAAFXk4AEAAAAAbFmHqXdw92r%2BQVP2WF42gl%2B8j24%3DXVjO9I6u1EhiLYoTkuzNoWVF6qk1N3DIg2xu7CWXee1ZTVe2Bq'

class MyStream(tweepy.StreamingClient):
    def on_tweet(self, tweet):
        # Send tweet data to the next step (preprocessing, DB, etc.)
        process_tweet(tweet)

# Set up streaming for a hashtag
stream = MyStream(BEARER_TOKEN)
stream.add_rules(tweepy.StreamRule("#AI"))
stream.filter(tweet_fields=["created_at", "lang", "geo"])
# Out:
# ---------------------------------------------------------------------------
# Forbidden                                 Traceback (most recent call last)
# Cell In[6], line 13
#      11 # Set up streaming for a hashtag
#      12 stream = MyStream(BEARER_TOKEN)
# ---> 13 stream.add_rules(tweepy.StreamRule("#AI"))
#      14 stream.filter(tweet_fields=["created_at", "lang", "geo"])
#
# File f:\Language Courses Videos\Machine Learning\Complete Data Science, Machine Learning, Deep Learning, NLP Bootcamp 2024-10\python\venv\Lib\site-packages\tweepy\streaming.py:333, in StreamingClient.add_rules(self, add, **params)
#     330     else:
#     331         json["add"].append({"value": rule.value})
# --> 333 return self._make_request(
#     334     "POST", f"/2/tweets/search/stream/rules", params=params,
#     335     endpoint_parameters=("dry_run",), json=json, data_type=StreamRule
#     336 )
#
# File f:\Language Courses Videos\Machine Learning\Complete Data Science, Machine Learning, Deep Learning, NLP Bootcamp 2024-10\python\venv\Lib\site-packages\tweepy\client.py:129, in BaseClient._make_request(self, method, route, params, endpoint_parameters, json, data_type, user_auth)
#     123 def _make_request(
#     124     self, method, route, params={}, endpoint_parameters=(), json=None,
#     125     data_type=None, user_auth=False
#     126 ):
#     127     request_params = self._process_params(params, endpoint_parameters)
# --> 129     response = self.request(method, route, params=request_params,
#     130                             json=json, user_auth=user_auth)
#     132     if self.return_type is requests.Response:
#     133         return response
#
# File f:\Language Courses Videos\Machine Learning\Complete Data Science, Machine Learning, Deep Learning, NLP Bootcamp 2024-10\python\venv\Lib\site-packages\tweepy\client.py:100, in BaseClient.request(self, method, route, params, json, user_auth)
#      98     raise Unauthorized(response)
#      99 if response.status_code == 403:
# --> 100     raise Forbidden(response)
#     101 if response.status_code == 404:
#     102     raise NotFound(response)
#
# Forbidden: 403 Forbidden
# When authenticating requests to the Twitter API v2 endpoints, you must use keys and tokens from a Twitter developer App that is attached to a Project. You can create a project via the developer portal.

# %% [markdown]
# 3. Preprocess Tweets

# %%
import re

def clean_text(text):
    text = re.sub(r"http\S+|@\S+|#\S+", "", text)
    text = re.sub(r"[^A-Za-z0-9 ]+", "", text)
    return text.strip().lower()

# %% [markdown]
# 4. BERT Sentiment Classification

# %%
from transformers import AutoTokenizer, AutoModelForSequenceClassification, pipeline

MODEL = "cardiffnlp/twitter-xlm-roberta-base-sentiment"
tokenizer = AutoTokenizer.from_pretrained(MODEL)
model = AutoModelForSequenceClassification.from_pretrained(MODEL)
sentiment_pipe = pipeline("sentiment-analysis", model=model, tokenizer=tokenizer)

def classify_sentiment(text):
    result = sentiment_pipe(text)
    return result[0]['label'], float(result[0]['score'])

# %% [markdown]
# 5. Store in MongoDB

# %%
from pymongo import MongoClient
from datetime import datetime

client = MongoClient("mongodb://localhost:27017/")
db = client.twitter_sentiment
collection = db.tweets

def save_tweet_to_db(tweet, sentiment, score, location):
    doc = {
        "text": tweet.text,
        "sentiment": sentiment,
        "score": score,
        "created_at": tweet.created_at,
        "location": location
    }
    collection.insert_one(doc)

# %% [markdown]
# 6. Tie All Steps Together

# %%
def process_tweet(tweet):
    clean = clean_text(tweet.text)
    sentiment, score = classify_sentiment(clean)
    loc = tweet.geo or "unknown"
    save_tweet_to_db(tweet, sentiment, score, loc)

# %% [markdown]
# 7. Streamlit Dashboard Example

# %%
import streamlit as st
import pandas as pd
import plotly.express as px

st.title("Twitter Sentiment Dashboard")

df = pd.DataFrame(list(collection.find()))
filter_date = st.date_input("Date")
filter_keyword = st.text_input("Keyword")
filter_location = st.text_input("Location")

# Filtering logic
if filter_date:
    df = df[df['created_at'].dt.date == pd.to_datetime(filter_date).date()]
if filter_keyword:
    df = df[df['text'].str.contains(filter_keyword, case=False)]
if filter_location:
    df = df[df['location'].str.contains(filter_location, case=False)]

# Visualizations
st.plotly_chart(px.histogram(df, x="sentiment", color="sentiment", title="Sentiment Distribution"))
st.dataframe(df[["text", "sentiment", "score", "created_at", "location"]])

# %% [markdown]
# 8. Auto-Generate Daily Report (CSV/PDF)

# %%
import pandas as pd

def export_daily_report(date):
    df = pd.DataFrame(list(collection.find({"created_at": {"$gte": date, "$lt": date + pd.Timedelta("1 day")}})))
    df.to_csv("daily_sentiment.csv", index=False)
    # For PDF, use reportlab/pdfkit etc.
# Out:
# Collecting tf-keras
#   Using cached tf_keras-2.19.0-py3-none-any.whl.metadata (1.8 kB)
# Collecting tensorflow<2.20,>=2.19 (from tf-ke
MB 6.8 MB/s eta 0:00:12
#    ------------------------------- -------- 298.6/376.0 MB 6.8 MB/s eta 0:00:12
#    ------------------------------- -------- 299.9/376.0 MB 6.8 MB/s eta 0:00:12
#    -------------------------------- ------- 301.2/376.0 MB 6.7 MB/s eta 0:00:12
#    -------------------------------- ------- 302.5/376.0 MB 6.7 MB/s eta 0:00:11
#    -------------------------------- ------- 303.8/376.0 MB 6.7 MB/s eta 0:00:11
#    -------------------------------- ------- 305.4/376.0 MB 6.6 MB/s eta 0:00:11
#    -------------------------------- ------- 307.2/376.0 MB 6.6 MB/s eta 0:00:11
#    -------------------------------- ------- 309.3/376.0 MB 6.6 MB/s eta 0:00:11
#    --------------------------------- ------ 310.9/376.0 MB 6.6 MB/s eta 0:00:10
#    --------------------------------- ------ 312.7/376.0 MB 6.5 MB/s eta 0:00:10
#    --------------------------------- ------ 314.8/376.0 MB 6.5 MB/s eta 0:00:10
#    --------------------------------- ------ 316.7/376.0 MB 6.5 MB/s eta 0:00:10
#    --------------------------------- ------ 318.8/376.0 MB 6.5 MB/s eta 0:00:09
#    ---------------------------------- ----- 320.6/376.0 MB 6.5 MB/s eta 0:00:09
#    ---------------------------------- ----- 322.4/376.0 MB 6.5 MB/s eta 0:00:09
#    ---------------------------------- ----- 324.3/376.0 MB 6.5 MB/s eta 0:00:08
#    ---------------------------------- ----- 326.1/376.0 MB 6.5 MB/s eta 0:00:08
#    ---------------------------------- ----- 327.9/376.0 MB 6.5 MB/s eta 0:00:08
#    ----------------------------------- ---- 330.0/376.0 MB 6.4 MB/s eta 0:00:08
#    ----------------------------------- ---- 331.4/376.0 MB 6.4 MB/s eta 0:00:07
#    ----------------------------------- ---- 332.7/376.0 MB 6.4 MB/s eta 0:00:07
#    ----------------------------------- ---- 334.0/376.0 MB 6.4 MB/s eta 0:00:07
#    ----------------------------------- ---- 335.8/376.0 MB 6.4 MB/s eta 0:00:07
#    ----------------------------------- ---- 337.4/376.0 MB 6.4 MB/s eta 0:00:07
#    ------------------------------------ --- 339.2/376.0 MB 6.4 MB/s eta 0:00:06
#    ------------------------------------ --- 340.8/376.0 MB 6.3 MB/s eta 0:00:06
#    ------------------------------------ --- 342.6/376.0 MB 6.3 MB/s eta 0:00:06
#    ------------------------------------ --- 344.5/376.0 MB 6.4 MB/s eta 0:00:05
#    ------------------------------------ --- 346.6/376.0 MB 6.4 MB/s eta 0:00:05
#    ------------------------------------- -- 348.7/376.0 MB 6.4 MB/s eta 0:00:05
#    ------------------------------------- -- 350.0/376.0 MB 6.4 MB/s eta 0:00:05
#    ------------------------------------- -- 352.1/376.0 MB 6.4 MB/s eta 0:00:04
#    ------------------------------------- -- 353.6/376.0 MB 6.4 MB/s eta 0:00:04
#    ------------------------------------- -- 355.5/376.0 MB 6.4 MB/s eta 0:00:04
#    ------------------------------------- -- 357.0/376.0 MB 6.4 MB/s eta 0:00:03
#    -------------------------------------- - 358.6/376.0 MB 6.4 MB/s eta 0:00:03
#    -------------------------------------- - 360.2/376.0 MB 6.4 MB/s eta 0:00:03
#    -------------------------------------- - 361.8/376.0 MB 6.4 MB/s eta 0:00:03
#    -------------------------------------- - 363.1/376.0 MB 6.4 MB/s eta 0:00:03
#    -------------------------------------- - 364.1/376.0 MB 6.4 MB/s eta 0:00:02
#    -------------------------------------- - 365.4/376.0 MB 6.3 MB/s eta 0:00:02
#    ---------------------------------------  367.0/376.0 MB 6.3 MB/s eta 0:00:02
#    ---------------------------------------  368.6/376.0 MB 6.3 MB/s eta 0:00:02
#    ---------------------------------------  369.9/376.0 MB 6.3 MB/s eta 0:00:01
#    ---------------------------------------  371.2/376.0 MB 6.2 MB/s eta 0:00:01
#    ---------------------------------------  372.0/376.0 MB 6.2 MB/s eta 0:00:01
#    ---------------------------------------  373.0/376.0 MB 6.2 MB/s eta 0:00:01
#    ---------------------------------------  373.8/376.0 MB 6.1 MB/s eta 0:00:01
#    ---------------------------------------  374.6/376.0 MB 6.1 MB/s eta 0:00:01
#    ---------------------------------------  375.4/376.0 MB 6.1 MB/s eta 0:00:01
#    ---------------------------------------  375.9/376.0 MB 6.1 MB/s eta 0:00:01
#    ---------------------------------------  375.9/376.0 MB 6.1 MB/s eta 0:00:01
#    ---------------------------------------- 376.0/376.0 MB 6.0 MB/s eta 0:00:00
# Downloading numpy-2.1.3-cp312-cp312-win_amd64.whl (12.6 MB)
#    ---------------------------------------- 0.0/12.6 MB ? eta -:--:--
#    -- ------------------------------------- 0.8/12.6 MB 3.7 MB/s eta 0:00:04
#    ---- ----------------------------------- 1.3/12.6 MB 3.4 MB/s eta 0:00:04
#    ------ --------------------------------- 2.1/12.6 MB 3.6 MB/s eta 0:00:03
#    --------- ------------------------------ 2.9/12.6 MB 3.6 MB/s eta 0:00:03
#    ----------- ---------------------------- 3.7/12.6 MB 3.7 MB/s eta 0:00:03
#    ------------- -------------------------- 4.2/12.6 MB 3.5 MB/s eta 0:00:03
#    --------------- ------------------------ 4.7/12.6 MB 3.4 MB/s eta 0:00:03
#    ----------------- ---------------------- 5.5/12.6 MB 3.4 MB/s eta 0:00:03
#    ------------------- -------------------- 6.0/12.6 MB 3.3 MB/s eta 0:00:02
#    --------------------- ------------------ 6.8/12.6 MB 3.3 MB/s eta 0:00:02
#    ------------------------ --------------- 7.6/12.6 MB 3.3 MB/s eta 0:00:02
#    -------------------------- ------------- 8.4/12.6 MB 3.4 MB/s eta 0:00:02
#    ------------------------------ --------- 9.4/12.6 MB 3.5 MB/s eta 0:00:01
#    -------------------------------- ------- 10.2/12.6 MB 3.5 MB/s eta 0:00:01
#    --------------------------------- ------ 10.5/12.6 MB 3.5 MB/s eta 0:00:01
#    ----------------------------------- ---- 11.0/12.6 MB 3.4 MB/s eta 0:00:01
#    ------------------------------------- -- 11.8/12.6 MB 3.3 MB/s eta 0:00:01
#    ---------------------------------------  12.3/12.6 MB 3.3 MB/s eta 0:00:01
#    ---------------------------------------- 12.6/12.6 MB 3.2 MB/s eta 0:00:00
# Using cached tensorboard-2.19.0-py3-none-any.whl (5.5 MB)
# Installing collected packages: numpy, tensorboard, tensorflow, tf-keras
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.2.1
#     Uninstalling numpy-2.2.1:
#       Successfully uninstalled numpy-2.2.1
#   Attempting uninstall: tensorboard
#     Found existing installation: tensorboard 2.20.0
#     Uninstalling tensorboard-2.20.0:
#       Successfully uninstalled tensorboard-2.20.0
#   Attempting uninstall: tensorflow
#     Found existing installation: tensorflow 2.20.0
#     Uninstalling tensorflow-2.20.0:
#       Successfully uninstalled tensorflow-2.20.0
# Successfully installed numpy-2.1.3 tensorboard-2.19.0 tensorflow-2.19.1 tf-keras-2.19.0
# Note: you may need to restart the kernel to use updated packages.
#   WARNING: Failed to remove contents in a temporary directory 'F:\Language Courses Videos\Machine Learning\Complete Data Science, Machine Learning, Deep Learning, NLP Bootcamp 2024-10\python\venv\Lib\site-packages\~umpy.libs'.
#   You can safely remove it manually.
#   WARNING: Failed to remove contents in a temporary directory 'F:\Language Courses Videos\Machine Learning\Complete Data Science, Machine Learning, Deep Learning, NLP Bootcamp 2024-10\python\venv\Lib\site-packages\~umpy'.
#   You can safely remove it manually.
#   WARNING: Failed to remove contents in a temporary directory 'F:\Language Courses Videos\Machine Learning\Complete Data Science, Machine Learning, Deep Learning, NLP Bootcamp 2024-10\python\venv\Lib\site-packages\~ensorflow'.
#   You can safely remove it manually.

# %%
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from dotenv import load_dotenv
#       2 import os
#       4 load_dotenv()  # this loads your .env file
#
# ModuleNotFoundError: No module named 'dotenv'
